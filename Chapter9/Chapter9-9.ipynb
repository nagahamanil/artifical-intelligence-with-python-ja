# %%
# p.217 9.9 Connect Four
import numpy as np
from easyAI import TwoPlayersGame, Human_Player, AI_Player, Negamax, SSS

# %%
class GameController(TwoPlayersGame):
    def __init__(self, players):
        self.players = players
        self.nplayer = 1
        
        self.board = np.zeros((6, 7), dtype=np.int)
        
        self.pos_dir = np.array(
        [[[i, 0], [0, 1]] for i in range(6)] + # 右方向
        [[[0, i], [1, 0]] for i in range(7)] + # 上方向
        [[[i, 0], [1, 1]] for i in range(1, 3)] + # 右上方向
        [[[0, i], [1, 1]] for i in range(4)] + # 右上方向
        [[[i, 6], [1, -1]] for i in range(1, 3)] + # 右下方向
        [[[0, i], [1, -1]] for i in range(3, 7)]) # 右下方向
    
    # 可能な手を列挙して返す
    def possible_moves(self):
#        return [i for i in range(7) if (self.board[:, i].min() == 0)]
        return np.random.permutation([i for i in range(7)
                                     if (self.board[:, i].min() == 0)])
    
    # 盤面を変化させるメソッド
    def make_move(self, column):
        line = np.argmin(self.board[:, column] != 0)
        self.board[line, column] = self.nplayer
        
    # 現在の状態を表示するメソッド
    def show(self):
        print('\n0 1 2 3 4 5 6')
        print(13 * '-')
        for j in range(5, -1, -1):
            print(' '.join(['.0X'[self.board[j][i]]
                           for i in range(7)]))
            
    # 負け判定メソッド 相手のコマが4つ以上連続しているか
    def loss_condition(self):
        for pos, direction in self.pos_dir:
            streak = 0
            while(0 <= pos[0] <= 5) and (0 <= pos[1] <= 6):
                if self.board[pos[0], pos[1]] == self.nopponent:
                    streak += 1
                    if streak == 4:
                        return True
                else:
                    streak = 0
                pos = pos + direction
        return False
    
    # ゲーム終了判定メソッド
    def is_over(self):
        return (self.board.min() > 0) or self.loss_condition()
    
    def scoring(self):
        return -100 if self.loss_condition() else 0

# %%
algo_neg = Negamax(5)
algo_sss = SSS(5)

game = GameController([AI_Player(algo_neg), AI_Player(algo_sss)])
game.play()

if game.loss_condition():
    print('\nPlayer', game.nopponent, 'wins. ')
else:
    print("\nIt's a draw.")
# Out:
# 0 1 2 3 4 5 6
# -------------
# . . . . . . .
# . . . . . . .
# . . . . . . .
# . . . . . . .
# . . . . . . .
# . . . . . . .
#
# Move #1: player 1 plays 3 :
#
# 0 1 2 3 4 5 6
# -------------
# . . . . . . .
# . . . . . . .
# . . . . . . .
# . . . . . . .
# . . . . . . .
# . . . 0 . . .
#
# Move #2: player 2 plays 0 :
#
# 0 1 2 3 4 5 6
# -------------
# . . . . . . .
# . . . . . . .
# . . . . . . .
# . . . . . . .
# . . . . . . .
# X . . 0 . . .
#
# Move #3: player 1 plays 5 :
#
# 0 1 2 3 4 5 6
# -------------
# . . . . . . .
# . . . . . . .
# . . . . . . .
# . . . . . . .
# . . . . . . .
# X . . 0 . 0 .
#
# Move #4: player 2 plays 4 :
#
# 0 1 2 3 4 5 6
# -------------
# . . . . . . .
# . . . . . . .
# . . . . . . .
# . . . . . . .
# . . . . . . .
# X . . 0 X 0 .
#
# Move #5: player 1 plays 2 :
#
# 0 1 2 3 4 5 6
# -------------
# . . . . . . .
# . . . . . . .
# . . . . . . .
# . . . . . . .
# . . . . . . .
# X . 0 0 X 0 .
#
# Move #6: player 2 plays 4 :
#
# 0 1 2 3 4 5 6
# -------------
# . . . . . . .
# . . . . . . .
# . . . . . . .
# . . . . . . .
# . . . . X . .
# X . 0 0 X 0 .
#
# Move #7: player 1 plays 0 :
#
# 0 1 2 3 4 5 6
# -------------
# . . . . . . .
# . . . . . . .
# . . . . . . .
# . . . . . . .
# 0 . . . X . .
# X . 0 0 X 0 .
#
# Move #8: player 2 plays 2 :
#
# 0 1 2 3 4 5 6
# -------------
# . . . . . . .
# . . . . . . .
# . . . . . . .
# . . . . . . .
# 0 . X . X . .
# X . 0 0 X 0 .
#
# Move #9: player 1 plays 6 :
#
# 0 1 2 3 4 5 6
# -------------
# . . . . . . .
# . . . . . . .
# . . . . . . .
# . . . . . . .
# 0 . X . X . .
# X . 0 0 X 0 0
#
# Move #10: player 2 plays 2 :
#
# 0 1 2 3 4 5 6
# -------------
# . . . . . . .
# . . . . . . .
# . . . . . . .
# . . X . . . .
# 0 . X . X . .
# X . 0 0 X 0 0
#
# Move #11: player 1 plays 3 :
#
# 0 1 2 3 4 5 6
# -------------
# . . . . . . .
# . . . . . . .
# . . . . . . .
# . . X . . . .
# 0 . X 0 X . .
# X . 0 0 X 0 0
#
# Move #12: player 2 plays 0 :
#
# 0 1 2 3 4 5 6
# -------------
# . . . . . . .
# . . . . . . .
# . . . . . . .
# X . X . . . .
# 0 . X 0 X . .
# X . 0 0 X 0 0
#
# Move #13: player 1 plays 2 :
#
# 0 1 2 3 4 5 6
# -------------
# . . . . . . .
# . . . . . . .
# . . 0 . . . .
# X . X . . . .
# 0 . X 0 X . .
# X . 0 0 X 0 0
#
# Move #14: player 2 plays 6 :
#
# 0 1 2 3 4 5 6
# -------------
# . . . . . . .
# . . . . . . .
# . . 0 . . . .
# X . X . . . .
# 0 . X 0 X . X
# X . 0 0 X 0 0
#
# Move #15: player 1 plays 6 :
#
# 0 1 2 3 4 5 6
# -------------
# . . . . . . .
# . . . . . . .
# . . 0 . . . .
# X . X . . . 0
# 0 . X 0 X . X
# X . 0 0 X 0 0
#
# Move #16: player 2 plays 2 :
#
# 0 1 2 3 4 5 6
# -------------
# . . . . . . .
# . . X . . . .
# . . 0 . . . .
# X . X . . . 0
# 0 . X 0 X . X
# X . 0 0 X 0 0
#
# Move #17: player 1 plays 3 :
#
# 0 1 2 3 4 5 6
# -------------
# . . . . . . .
# . . X . . . .
# . . 0 . . . .
# X . X 0 . . 0
# 0 . X 0 X . X
# X . 0 0 X 0 0
#
# Move #18: player 2 plays 3 :
#
# 0 1 2 3 4 5 6
# -------------
# . . . . . . .
# . . X . . . .
# . . 0 X . . .
# X . X 0 . . 0
# 0 . X 0 X . X
# X . 0 0 X 0 0
#
# Move #19: player 1 plays 5 :
#
# 0 1 2 3 4 5 6
# -------------
# . . . . . . .
# . . X . . . .
# . . 0 X . . .
# X . X 0 . . 0
# 0 . X 0 X 0 X
# X . 0 0 X 0 0
#
# Move #20: player 2 plays 5 :
#
# 0 1 2 3 4 5 6
# -------------
# . . . . . . .
# . . X . . . .
# . . 0 X . . .
# X . X 0 . X 0
# 0 . X 0 X 0 X
# X . 0 0 X 0 0
#
# Move #21: player 1 plays 3 :
#
# 0 1 2 3 4 5 6
# -------------
# . . . . . . .
# . . X 0 . . .
# . . 0 X . . .
# X . X 0 . X 0
# 0 . X 0 X 0 X
# X . 0 0 X 0 0
#
# Move #22: player 2 plays 1 :
#
# 0 1 2 3 4 5 6
# -------------
# . . . . . . .
# . . X 0 . . .
# . . 0 X . . .
# X . X 0 . X 0
# 0 . X 0 X 0 X
# X X 0 0 X 0 0
#
# Move #23: player 1 plays 1 :
#
# 0 1 2 3 4 5 6
# -------------
# . . . . . . .
# . . X 0 . . .
# . . 0 X . . .
# X . X 0 . X 0
# 0 0 X 0 X 0 X
# X X 0 0 X 0 0
#
# Move #24: player 2 plays 1 :
#
# 0 1 2 3 4 5 6
# -------------
# . . . . . . .
# . . X 0 . . .
# . . 0 X . . .
# X X X 0 . X 0
# 0 0 X 0 X 0 X
# X X 0 0 X 0 0
#
# Move #25: player 1 plays 3 :
#
# 0 1 2 3 4 5 6
# -------------
# . . . 0 . . .
# . . X 0 . . .
# . . 0 X . . .
# X X X 0 . X 0
# 0 0 X 0 X 0 X
# X X 0 0 X 0 0
#
# Move #26: player 2 plays 6 :
#
# 0 1 2 3 4 5 6
# -------------
# . . . 0 . . .
# . . X 0 . . .
# . . 0 X . . X
# X X X 0 . X 0
# 0 0 X 0 X 0 X
# X X 0 0 X 0 0
#
# Move #27: player 1 plays 0 :
#
# 0 1 2 3 4 5 6
# -------------
# . . . 0 . . .
# . . X 0 . . .
# 0 . 0 X . . X
# X X X 0 . X 0
# 0 0 X 0 X 0 X
# X X 0 0 X 0 0
#
# Move #28: player 2 plays 5 :
#
# 0 1 2 3 4 5 6
# -------------
# . . . 0 . . .
# . . X 0 . . .
# 0 . 0 X . X X
# X X X 0 . X 0
# 0 0 X 0 X 0 X
# X X 0 0 X 0 0
#
# Move #29: player 1 plays 0 :
#
# 0 1 2 3 4 5 6
# -------------
# . . . 0 . . .
# 0 . X 0 . . .
# 0 . 0 X . X X
# X X X 0 . X 0
# 0 0 X 0 X 0 X
# X X 0 0 X 0 0
#
# Move #30: player 2 plays 2 :
#
# 0 1 2 3 4 5 6
# -------------
# . . X 0 . . .
# 0 . X 0 . . .
# 0 . 0 X . X X
# X X X 0 . X 0
# 0 0 X 0 X 0 X
# X X 0 0 X 0 0
#
# Move #31: player 1 plays 0 :
#
# 0 1 2 3 4 5 6
# -------------
# 0 . X 0 . . .
# 0 . X 0 . . .
# 0 . 0 X . X X
# X X X 0 . X 0
# 0 0 X 0 X 0 X
# X X 0 0 X 0 0
#
# Move #32: player 2 plays 5 :
#
# 0 1 2 3 4 5 6
# -------------
# 0 . X 0 . . .
# 0 . X 0 . X .
# 0 . 0 X . X X
# X X X 0 . X 0
# 0 0 X 0 X 0 X
# X X 0 0 X 0 0
#
# Move #33: player 1 plays 5 :
#
# 0 1 2 3 4 5 6
# -------------
# 0 . X 0 . 0 .
# 0 . X 0 . X .
# 0 . 0 X . X X
# X X X 0 . X 0
# 0 0 X 0 X 0 X
# X X 0 0 X 0 0
#
# Move #34: player 2 plays 6 :
#
# 0 1 2 3 4 5 6
# -------------
# 0 . X 0 . 0 .
# 0 . X 0 . X X
# 0 . 0 X . X X
# X X X 0 . X 0
# 0 0 X 0 X 0 X
# X X 0 0 X 0 0
#
# Move #35: player 1 plays 6 :
#
# 0 1 2 3 4 5 6
# -------------
# 0 . X 0 . 0 0
# 0 . X 0 . X X
# 0 . 0 X . X X
# X X X 0 . X 0
# 0 0 X 0 X 0 X
# X X 0 0 X 0 0
#
# Move #36: player 2 plays 1 :
#
# 0 1 2 3 4 5 6
# -------------
# 0 . X 0 . 0 0
# 0 . X 0 . X X
# 0 X 0 X . X X
# X X X 0 . X 0
# 0 0 X 0 X 0 X
# X X 0 0 X 0 0
#
# Move #37: player 1 plays 1 :
#
# 0 1 2 3 4 5 6
# -------------
# 0 . X 0 . 0 0
# 0 0 X 0 . X X
# 0 X 0 X . X X
# X X X 0 . X 0
# 0 0 X 0 X 0 X
# X X 0 0 X 0 0
#
# Player 1 wins.
