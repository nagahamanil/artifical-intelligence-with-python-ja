# %%
# p.366 15.8 エージェントの例2
import gym
import numpy as np
import random

class Agent:
    def __init__(self):
        self.Q = np.zeros((5**4, 2))
        self.last_s = None
        self.last_a = None
        
    def quantize5(self, x, a, b):
        return 0 if x < -a else 1 if x < -b else 2 if x <= b else 3 if x <= a else 4
    
    def quantize(self, obs):
        pos = self.quantize5(obs[0], 1.2, 0.2)
        vel = self.quantize5(obs[1], 1.5, 0.2)
        ang = self.quantize5(obs[2], 0.25, 0.02)
        acc = self.quantize5(obs[2], 1.0, 0.2)
        return pos + vel * 5 + ang * 25 + acc * 125
    
    def action(self, obs, episode, reward):
        s = self.quantize(obs)
        if random.random() > 0.5 * (1 / (episode + 1)):
            a = np.argmax(self.Q[s,:])
        else:
            a = random.randint(0, 1)
        
        if self.last_s is not None:
            q = self.Q[self.last_s, self.last_a]
            self.Q[self.last_s, self.last_a] = q + 0.2 * (reward + 0.99 * np.max(self.Q[s,:]) - q)
        self.last_s = s
        self.last_a = a
        return a

# %%
agent = Agent()

env = gym.make('CartPole-v1')
steps = []
for episode in range(100):
    observation = env.reset()
    
    reward = 0
    for step in range(200):
        env.render()
        action = agent.action(observation, episode, reward)
        observation, reward, done, info = env.step(action)
        
        if done:
            agent.action(observation, episode, -200)
            break
    
    print('Episode {} finished after {} timesteps'.format(episode+1, step+1))
    steps.append(step+1)
env.close()
# Out:
# Episode 1 finished after 15 timesteps
# Episode 2 finished after 25 timesteps
# Episode 3 finished after 18 timesteps
# Episode 4 finished after 63 timesteps
# Episode 5 finished after 25 timesteps
# Episode 6 finished after 17 timesteps
# Episode 7 finished after 21 timesteps
# Episode 8 finished after 10 timesteps
# Episode 9 finished after 10 timesteps
# Episode 10 finished after 29 timesteps
# Episode 11 finished after 8 timesteps
# Episode 12 finished after 22 timesteps
# Episode 13 finished after 27 timesteps
# Episode 14 finished after 9 timesteps
# Episode 15 finished after 21 timesteps
# Episode 16 finished after 10 timesteps
# Episode 17 finished after 9 timesteps
# Episode 18 finished after 22 timesteps
# Episode 19 finished after 20 timesteps
# Episode 20 finished after 43 timesteps
# Episode 21 finished after 65 timesteps
# Episode 22 finished after 76 timesteps
# Episode 23 finished after 46 timesteps
# Episode 24 finished after 66 timesteps
# Episode 25 finished after 22 timesteps
# Episode 26 finished after 18 timesteps
# Episode 27 finished after 11 timesteps
# Episode 28 finished after 9 timesteps
# Episode 29 finished after 8 timesteps
# Episode 30 finished after 40 timesteps
# Episode 31 finished after 55 timesteps
# Episode 32 finished after 82 timesteps
# Episode 33 finished after 119 timesteps
# Episode 34 finished after 48 timesteps
# Episode 35 finished after 36 timesteps
# Episode 36 finished after 15 timesteps
# Episode 37 finished after 13 timesteps
# Episode 38 finished after 9 timesteps
# Episode 39 finished after 9 timesteps
# Episode 40 finished after 13 timesteps
# Episode 41 finished after 9 timesteps
# Episode 42 finished after 63 timesteps
# Episode 43 finished after 175 timesteps
# Episode 44 finished after 50 timesteps
# Episode 45 finished after 100 timesteps
# Episode 46 finished after 66 timesteps
# Episode 47 finished after 78 timesteps
# Episode 48 finished after 63 timesteps
# Episode 49 finished after 55 timesteps
# Episode 50 finished after 131 timesteps
# Episode 51 finished after 200 timesteps
# Episode 52 finished after 188 timesteps
# Episode 53 finished after 200 timesteps
# Episode 54 finished after 75 timesteps
# Episode 55 finished after 200 timesteps
# Episode 56 finished after 57 timesteps
# Episode 57 finished after 200 timesteps
# Episode 58 finished after 200 timesteps
# Episode 59 finished after 188 timesteps
# Episode 60 finished after 200 timesteps
# Episode 61 finished after 198 timesteps
# Episode 62 finished after 18 timesteps
# Episode 63 finished after 47 timesteps
# Episode 64 finished after 122 timesteps
# Episode 65 finished after 65 timesteps
# Episode 66 finished after 22 timesteps
# Episode 67 finished after 200 timesteps
# Episode 68 finished after 200 timesteps
# Episode 69 finished after 200 timesteps
# Episode 70 finished after 199 timesteps
# Episode 71 finished after 179 timesteps
# Episode 72 finished after 200 timesteps
# Episode 73 finished after 200 timesteps
# Episode 74 finished after 200 timesteps
# Episode 75 finished after 200 timesteps
# Episode 76 finished after 200 timesteps
# Episode 77 finished after 64 timesteps
# Episode 78 finished after 196 timesteps
# Episode 79 finished after 116 timesteps
# Episode 80 finished after 172 timesteps
# Episode 81 finished after 200 timesteps
# Episode 82 finished after 149 timesteps
# Episode 83 finished after 147 timesteps
# Episode 84 finished after 157 timesteps
# Episode 85 finished after 79 timesteps
# Episode 86 finished after 92 timesteps
# Episode 87 finished after 200 timesteps
# Episode 88 finished after 131 timesteps
# Episode 89 finished after 54 timesteps
# Episode 90 finished after 145 timesteps
# Episode 91 finished after 105 timesteps
# Episode 92 finished after 122 timesteps
# Episode 93 finished after 127 timesteps
# Episode 94 finished after 103 timesteps
# Episode 95 finished after 200 timesteps
# Episode 96 finished after 184 timesteps
# Episode 97 finished after 162 timesteps
# Episode 98 finished after 200 timesteps
# Episode 99 finished after 200 timesteps
# Episode 100 finished after 200 timesteps

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure()
plt.plot(steps)
plt.xlabel('Episode')
plt.ylabel('Step')
plt.show()
