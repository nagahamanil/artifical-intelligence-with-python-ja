# %%
# p.364 15.7 エージェントの例
import gym

env = gym.make('CartPole-v1')
steps = []
for episode in range(20):
    observation = env.reset()
    
    for step in range(100):
        env.render()
        _,_,th,_ = observation
        if th < 0:
            action = 0
        else:
            action = 1
            
        observation, reward, done, info = env.step(action)
        if done: break
            
    print('Episode {} finished after {} timesteps'.format(episode+1, step+1))
    steps.append(step+1)
env.close()
# Out:
# Episode 1 finished after 41 timesteps
# Episode 2 finished after 51 timesteps
# Episode 3 finished after 31 timesteps
# Episode 4 finished after 56 timesteps
# Episode 5 finished after 51 timesteps
# Episode 6 finished after 57 timesteps
# Episode 7 finished after 42 timesteps
# Episode 8 finished after 34 timesteps
# Episode 9 finished after 50 timesteps
# Episode 10 finished after 36 timesteps
# Episode 11 finished after 37 timesteps
# Episode 12 finished after 41 timesteps
# Episode 13 finished after 42 timesteps
# Episode 14 finished after 52 timesteps
# Episode 15 finished after 37 timesteps
# Episode 16 finished after 43 timesteps
# Episode 17 finished after 26 timesteps
# Episode 18 finished after 35 timesteps
# Episode 19 finished after 51 timesteps
# Episode 20 finished after 31 timesteps

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure()
plt.plot(steps)
plt.xlabel('Episode')
plt.ylabel('Step')
plt.show()
